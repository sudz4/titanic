# %%
import pandas as pd

# %%
""" 
I am trying to determine scenarios where these bros could have survived.
Using historical texts and other scenarios, like if they had me coaching them in an earphone how to escape.
"""

# %%
# load the almost completeley dead bros from 3rd class that got on in Queenstown
bros_3rd_df = pd.read_csv('bros_3rd_class.csv')

# verify your bros are here
bros_3rd_df
# Out:
#     PassengerId  Survived  Pclass                          Name   Sex   Age  \
# 0             6         0       3              Moran, Mr. James  male   NaN
# 1            17         0       3          Rice, Master. Eugene  male   2.0
# 2            47         0       3             Lennon, Mr. Denis  male   NaN
# 3           117         0       3          Connors, Mr. Patrick  male  70.5
# 4           127         0       3           McMahon, Mr. Martin  male   NaN
# 5           144         0       3           Burke, Mr. Jeremiah  male  19.0
# 6           172         0       3          Rice, Master. Arthur  male   4.0
# 7           189         0       3              Bourke, Mr. John  male  40.0
# 8           197         0       3           Mernagh, Mr. Robert  male   NaN
# 9           215         0       3           Kiernan, Mr. Philip  male   NaN
# 10          261         0       3             Smith, Mr. Thomas  male   NaN
# ...
